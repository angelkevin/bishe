# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome("C:\Program Files\Google\Chrome\Application\chromedriver.exe")

# %%
driver.get('http://quote.eastmoney.com/center/gridlist.html#kcb_board')

# %%
mm = driver.find_element(by=By.XPATH, value='//*[@id="main-table_paginate"]/span[1]/a[5]').text

# %%
result = []
for ww in range(0, int(mm)):
    soup = BeautifulSoup(driver.page_source)
    x = soup.find_all(id="table_wrapper-table")
    cc = x[0]
    dd = cc.findAllNext('td')
    m = 0
    driver.find_element(by=By.XPATH, value='/html/body/div[1]/div[2]/div[2]/div[5]/div/div[2]/div/a[2]').click()

    for i in range(int(len(dd) / 20.0) + 1):
        l = []
        tt = dd[m:m + 19]
        l.append(tt[0].text)
        l.append(tt[1].text)
        l.append(tt[2].text)
        if str(tt[4]).split("\"")[3] == 'red':
            l.append(tt[4].text)
        elif str(tt[4]).split("\"")[3] == 'green':
            l.append('-' + tt[4].text)
        else:
            l.append(tt[4].text)
        l.append(tt[5].text)
        if str(tt[6]).split("\"")[1] == 'red':
            l.append(tt[6].text)
        else:
            l.append(tt[6].text)
        l.append(tt[7].text)
        l.append(tt[8].text)
        l.append(tt[9].text)
        l.append(tt[10].text)
        l.append(tt[11].text)
        l.append(tt[12].text)
        l.append(tt[13].text)
        l.append(tt[14].text)
        l.append(tt[15].text)
        l.append(tt[16].text)
        l.append(tt[17].text)
        m = m + 19
        result.append(l)
driver.close()

# %%
import pandas as pd

# %%
data = pd.DataFrame(result, columns=[
    'serial_number',
    'code',
    'name',
    'latest_price',
    'rise_and_fall',
    'rise_and_fall_amount',
    'volume',
    'turnover',
    'amplitude',
    'highest',
    'lowest',
    'open_today',
    'yesterday',
    'volume_ratio',
    'turnover_rate',
    'ratio_p/b',
    'ratio'
])

# %%
data
# Out:
#     serial_number    code    name latest_price rise_and_fall  \
# 0               1  688466    金科环境        22.74        20.00%
# 1               2  688247    宣泰医药        18.03         8.35%
# 2               3  688162    巨一科技        53.44         5.95%
# 3               4  688338    赛科希德        46.22         5.21%
# 4               5  688683    莱尔科技        25.46         4.99%
# ..            ...     ...     ...          ...           ...
# 504           505  688191    智洋创新       -15.12        -7.41%
# 505           506  688316  青云科技-U       -41.20        -7.99%
# 506           507  688229    博睿数据       -44.09        -9.00%
# 507           508  688619     罗普特       -13.81       -10.09%
# 508           509  688579    山大地纬       -10.98       -10.37%
#
#     rise_and_fall_amount  volume  turnover amplitude highest lowest  \
# 0                   3.79   7.84万     1.72亿    18.52%   22.74  19.23
# 1                   1.39  19.56万     3.43亿    13.22%   18.56  16.36
# ...

# %%
sql = """CREATE TABLE stock_market_data(
`serial_number`   varchar(20)               COMMENT '序号',
`code`   varchar(20)             COMMENT '代码	',
`name`   varchar(255)             COMMENT '名称',
`latest_price`   varchar(255)              COMMENT '最新价',
`rise_and_fall`   varchar(255)                COMMENT '涨跌幅',
`rise_and_fall_amount`   varchar(255)              COMMENT '涨跌额',
`volume`   varchar(255)            COMMENT '成交量',
`turnover`   varchar(255)               COMMENT '成交额',
`amplitude`   varchar(255)             COMMENT '振幅',
`highest`   varchar(255)           COMMENT '最高',
`lowest`   varchar(255)             COMMENT '最低',
`open_today`   varchar(255)              COMMENT '今开',
`yesterday`   varchar(255)               COMMENT '作收',
`volume_ratio`   varchar(255)             COMMENT '量比',
`turnover_rate`   varchar(255)               COMMENT '换手率',
`ratio_p/b`   varchar(255)              COMMENT '市盈率',
`ratio`   varchar(255)               COMMENT '市净率',
`create_time` varchar(255)                 COMMENT '创建时间')"""

# %%
, columns=[
'serial_number',
'code',
'name',
'latest_price',
'rise_and_fall',
'rise_and_fall_amount',
'volume',
'turnover',
'amplitude',
'highest',
'lowest',
'open_today',
'yesterday',
'volume_ratio',
'turnover_rate',
'ratio_p/b',
'ratio'
]

# %%
import pymysql

# %%
conn = pymysql.connect(host='127.0.0.1', user='root', password='')

# %%
cur = conn.cursor()

# %%
cur.execute('select * from gpdb.stock_market_data')
cur.fetchall()
# Out:
# (('1',
#   '832149',
#   'N利尔达',
#   '6.98',
#   '0.4',
#   '1.98',
#   '290900.0',
#   '208000000.0',
#   '0.37',
#   '8.35',
#   '6.50',
#   '6.50',
#   '5.00',
#   '36.73',
#   '0.26',
#   '23.37',
#   '3.61',
#   '2023-02-18'),
#  ('2',
#   '832735',
#   '德源药业',
#   '32.70',
#   '0.13',
#   '3.83',
#   '20300.0',
#   '63480800.0',
#   '0.18',
#   '33.60',
#   '28.40',
#   '28.46',
#   '28.87',
#   '1.97',
#   '0.05',
#   '22.80',
#   '2.79',
#   '2023-02-18'),
#  ('3',
#   '834033',
#   '康普化学',
#   '31.48',
#   '0.05',
#   '1.62',
#   '6903',
#   '21488400.0',
#   '0.11',
#   '32.30',
#   '29.13',
#   '29.51',
#   '29.86',
#   '1.40',
#   '0.02',
#   '27.66',
#   '5.68',
#   '2023-02-18'),
#  ('4',
#   '833533',
#   '骏创科技',
#   '20.19',
#   '0.05',
#   '1.01',
#   '9584',
#   '19103400.0',
#   '0.08',
#   '20.50',
#   '19.02',
#   '19.12',
#   '19.18',
#   '5.18',
#   '0.05',
#   '18.73',
#   '4.53',
#   '2023-02-18'),
#  ('5',
#   '830946',
#   '森萱医药',
#   '9.55',
#   '0.04',
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://s.weibo.com/top/summary?Refer=top_hot&topnav=1&wvr=6'

response = requests.get(url)
print(response)
soup = BeautifulSoup(response.text, 'html.parser')

# 获取热搜列表
hot_list = soup.find('tbody')
print(hot_list)

# 输出热搜排名和标题
for hot in hot_list:
    rank = hot.find(class_='td-01').text.strip()
    title = hot.find(class_='td-02').text.strip()
    print(rank, title)
# Out:
# <Response [200]>
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 15>()
#      12 print(hot_list)
#      14 # 输出热搜排名和标题
# ---> 15 for hot in hot_list:
#      16     rank = hot.find(class_='td-01').text.strip()
#      17     title = hot.find(class_='td-02').text.strip()
#
# TypeError: 'NoneType' object is not iterable

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
import pandas as pd
import threading
import pymysql
from sqlalchemy import create_engine

pymysql.install_as_MySQLdb()
DB_STRING = "mysql+mysqldb://root:@127.0.0.1/gpdb"
engine = create_engine(DB_STRING)
URLs = [
    'https://quote.eastmoney.com/center/gridlist.html#sz_a_board',
    'https://quote.eastmoney.com/center/gridlist.html#hs_a_board',
    'https://quote.eastmoney.com/center/gridlist.html#bj_a_board',
    'https://quote.eastmoney.com/center/gridlist.html#sh_a_board',
    'https://quote.eastmoney.com/center/gridlist.html#gem_board',
    'https://quote.eastmoney.com/center/gridlist.html#kcb_board',
    'https://quote.eastmoney.com/center/gridlist.html#b_board']

options = Options()
options.add_argument('--headless')


def spider(url):
    result = []
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    page_num = driver.find_element(by=By.XPATH, value='//*[@id="main-table_paginate"]/span[1]/a[5]').text
    for i in range(0, int(page_num)):
        soup = BeautifulSoup(driver.page_source, 'html.parser')

        massage = soup.find_all(id="table_wrapper-table")
        page = massage[0]
        page_massage = page.findAllNext('td')
        m = 0
        for j in range(int(len(page_massage) / 20.0) + 1):
            l = []
            tt = page_massage[m:m + 19]
            l.append(tt[0].text)

            l.append(tt[1].text)

            l.append(tt[2].text)

            if str(tt[4]).split("\"")[3] == 'red':
                l.append(tt[4].text)
            elif str(tt[4]).split("\"")[3] == 'green':
                l.append('-' + tt[4].text)
            else:
                l.append(tt[4].text)

            if "%" in tt[5].text:
                l.append(str(round(float(tt[5].text.split("%")[0]) * 0.01, 2)))
            else:
                l.append(tt[5].text)

            if str(tt[6]).split("\"")[1] == 'red':
                l.append(tt[6].text)
            else:
                l.append(tt[6].text)

            if "万" in tt[7].text:
                l.append(str(round(float(tt[7].text.split("万")[0]) * 10000, 2)))
            elif "亿" in tt[7].text:
                l.append(str(round(float(tt[7].text.split("万")[0]) * 100000000, 2)))
            else:
                l.append(tt[7].text)

            if "万" in tt[8].text:
                l.append(str(round(float(tt[8].text.split("万")[0]) * 10000, 2)))
            elif "亿" in tt[8].text:
                l.append(str(round(float(tt[8].text.split("亿")[0]) * 100000000, 2)))
            else:
                l.append(tt[8].text)

            if "%" in tt[9].text:
                l.append(str(round(float(tt[9].text.split("%")[0]) * 0.01, 2)))
            else:
                l.append(tt[9].text)

            l.append(tt[10].text)
            l.append(tt[11].text)
            l.append(tt[12].text)
            l.append(tt[13].text)
            l.append(tt[14].text)

            if "%" in tt[15].text:
                l.append(str(round(float(tt[15].text.split("%")[0]) * 0.01, 2)))
            else:
                l.append(tt[15].text)
            l.append(tt[16].text)
            l.append(tt[17].text)
            m = m + 19
            result.append(l)
        driver.find_element(by=By.XPATH, value='/html/body/div[1]/div[2]/div[2]/div[5]/div/div[2]/div/a[2]').click()
        time.sleep(1)
    print(len(result))
    return result


def save_data(data, name):
    today = time.strftime('%Y-%m-%d-%H', time.localtime())
    df = pd.DataFrame(data, columns=[
        'serial_number',
        'code',
        'name',
        'latest_price',
        'rise_and_fall',
        'rise_and_fall_amount',
        'volume',
        'turnover',
        'amplitude',
        'highest',
        'lowest',
        'open_today',
        'yesterday',
        'volume_ratio',
        'turnover_rate',
        'ratio_p/b',
        'ratio'
    ])
    df = df.replace('-', '0')
    df = df.drop_duplicates(subset=['code'], keep='first')
    df.insert(17, 'create_time', str(today), allow_duplicates=False)
    df.to_sql('stock_market_data', con=engine, chunksize=10000, if_exists='append', index=False)
    df.to_csv(path_or_buf=f"D:/Python/bi/data/{name}_{today}.csv", index=False, header=False, encoding="UTF-8")


class myThread(threading.Thread):
    def __init__(self, name, link_range):
        threading.Thread.__init__(self)
        self.name = name
        self.link_range = link_range

    def run(self):
        print("Starting " + self.name)
        crawl(self.name, self.link_range)
        print("Exiting " + self.name)


def crawl(threadNmae, link_range):
    for i in range(link_range[0], link_range[1] + 1):
        try:
            data = spider(URLs[i])
            print(URLs[i])
            save_data(data, URLs[i].split('#')[1])
        except Exception as e:
            print(threadNmae, "Error: ", e)


threads = []
link_range_list = [(0, 1), (2, 3), (4, 5, 6)]

if __name__ == '__main__':

    for i in range(1, 4):
        thread = myThread("Thread-" + str(i), link_range=link_range_list[i - 1])
        thread.start()
        threads.append(thread)

    for thread in threads:
        thread.join()
# Out:
# Thread-1 Error:  Message: element click intercepted: Element <a class="next paginate_button disabled" data-index="266">...</a> is not clickable at point (701, 12). Other element would receive the click: <a target="_blank" href="http://gb.eastmoney.com/" class="category">...</a>
#   (Session info: headless chrome=110.0.5481.104)
#
# Exiting Thread-1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 157>()
#     162     threads.append(thread)
#     164 for thread in threads:
# --> 165     thread.join()
#
# File ~\Anaconda3\lib\threading.py:1053, in Thread.join(self, timeout)
#    1050     raise RuntimeError("cannot join current thread")
#    1052 if timeout is None:
# -> 1053     self._wait_for_tstate_lock()
#    1054 else:
#    1055     # the behavior of a negative timeout isn't documented, but
# ...
